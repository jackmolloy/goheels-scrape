# %%
#I really couldn't figure out how to do this. 
#The stats werent being written into my json file, despite me following your example step by step. 
#There wasn't much manipulation I could do with the dataframe without the stats.

# %%
import numpy as np
import pandas as pd
import json

# %%
#creating a dataframe from baseball json
df = pd.read_json("baseball_team_SCRAPED.json")

# %%
df
# Out:
#      # Academic Year             Full Name  \
# 0    1           Jr.         Brandon Riley
# 1    2           Fr.    Satchel Jerzembeck
# 2    3           Jr.           Kyle Datres
# 3    4           So.     Brandon Martorano
# 4    5           So.          Ashton McGee
# 5    6           Jr.        Dylan Enwiller
# 6    7         R-So.         Dallas Tessar
# 7    8           So.           Ike Freeman
# 8   10           Sr.          Zack Gahagan
# 9   11           Jr.          Cody Roberts
# 10  12           Jr.         Josh Ladowski
# 11  15           So.         Michael Busch
# 12  16           Fr.           Earl Semper
# 13  18           Fr.       Clemente Inclan
# 14  19           Sr.         Brett Daniels
# 15  23           So.            Tyler Baum
# 16  24         R-Jr.         Hansen Butler
# 17  25           Jr.           Taylor Sugg
# 18  26           Jr.     Jackson Hesterlee
# 19  27         R-Jr.          Jason Morgan
# 20  29           Jr.            Trevor Gay
# ...
